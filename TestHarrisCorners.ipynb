# %%
# %cd /content/drive/MyDrive/CIS3/Assignments/First/MainCode
# Out:
# /content/drive/MyDrive/CIS3/Assignments/First/MainCode

# %%
from PIL import Image
from numpy import *
from pylab import *
import harris2

# %%
im = array(Image.open('/content/drive/MyDrive/CIS3/Assignments/First/Images/hara1.jpg').convert('L'))
harrisim = harris2.compute_harris_response(im,3)
corners = harris2.get_harris_points(harrisim,10,0.1)
print(len(corners))
harris2.plot_harris_corners(im,corners)
# Out:
# 206
